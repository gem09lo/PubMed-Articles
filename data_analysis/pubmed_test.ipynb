# %% [markdown]
# ## This notebook runs on a smaller sample for development/testing

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import xml.etree.ElementTree as ET
import re
# pip install spacy
# python -m spacy download en_core_web_sm
import spacy
import pycountry
from rapidfuzz import process, fuzz
from rapidfuzz.distance import Levenshtein
import rapidfuzz

# %% [markdown]
# ## Read File

# %%
tree = ET.parse('../raw_data/c14-gem-lo-pubmed.xml')
root = tree.getroot()

# %% [markdown]
# # Create base dataframe

# %%
def parse_article_metadata(article):
    """Returns article pmid, title and year."""
    pmid_value = article.find(".//PMID").text
    title_value = article.find(".//ArticleTitle").text
    year_value = article.find(".//PubDate/Year")

    return pmid_value, title_value, year_value.text if year_value is not None else ""

# %%
def parse_author_info(author):
    """Returns author information"""
    last_name = author.find("LastName")
    first_name = author.find("ForeName")

    if last_name is not None and first_name is not None:
        return f"{last_name.text} {first_name.text}"
    elif last_name is not None:
        return last_name.text
    elif first_name is not None:
        return first_name.text
    else:
        return ""

# %%
def get_email(affiliation_text):
    """Extracts the email from affiliation name using regex"""
    email_address = re.search(r"[\w.]+@[\w.]+\w+", affiliation_text)
    return email_address.group() if email_address else ""

# %%
def get_zipcode(affiliation_text):
    """Extracts zipcode from affiliation name using regex"""
    zip_code = re.search(
        r"[A-Za-z]{1,2}\d[A-Za-z\d]? ?\d[A-Za-z]{2}|\d{5}(-\d{4})?|[A-Z]\d[A-Z] \d[A-Z]\d", affiliation_text)
    return zip_code.group() if zip_code else ""

# %%
def get_keywords(article):
    """Returns keywords for each article"""
    keywords_element = article.findall(".//KeywordList/Keyword")
    return [keyword.text for keyword in keywords_element] if keywords_element else [""]

# %%
def get_mesh_identifiers(article):
    """Returns mesh identifiers UI for each article"""
    mesh_elements = article.findall(
        ".//MeshHeadingList/MeshHeading/DescriptorName")
    return [mesh.get("UI") for mesh in mesh_elements] if mesh_elements else [""]

# %%
pmid, title, author_name, affiliation_name, year = [], [], [], [], []
mesh_identifiers, keywords, email, zipcode = [], [], [], []

for article in root.findall("PubmedArticle"):
    pmid_value, title_value, year_value = parse_article_metadata(article)

    for author in article.findall(".//AuthorList/Author"):
        for affiliation in author.findall("AffiliationInfo/Affiliation"):
            pmid.append(pmid_value)
            title.append(title_value)
            year.append(year_value)

            author_name.append(parse_author_info(author))

            affiliation_text = affiliation.text
            affiliation_name.append(affiliation_text)

            email.append(get_email(affiliation_text))
            zipcode.append(get_zipcode(affiliation_text))

            keywords.append(get_keywords(article))
            mesh_identifiers.append(get_mesh_identifiers(article))

pubmed_df = pd.DataFrame({
    "Article PMID": pmid,
    "Article title": title,
    "Article keywords": keywords,
    "Article MESH identifiers": mesh_identifiers,
    "Article Year": year,
    "Author full name": author_name,
    "Author email": email,
    "Affiliation name": affiliation_name,
    "Affiliation zipcode": zipcode
})

pubmed_df.to_csv("../cleaned_data/pubmed_output_test.csv", index=False)

#took 4 secs

# %% [markdown]
# # Challenge 3: NLP

# %%
# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# **Extract country and institution name from affiliation**

# %%
def extract_entities(affiliation_text):
    """Returns the entities of each affiliation(First affiliaiton name column)"""
    doc = nlp(affiliation_text)
    entities = doc.ents

    return entities

entities = extract_entities(affiliation_text)

def extract_gpe_entities(entities):
    gpe_entities = {
        entity.text for entity in reversed(entities) if entity.label_ == "GPE"}
    return gpe_entities


def extract_org_entities(entities):
    org_entities = {
        entity.text for entity in entities if entity.label_ == "ORG"}
    return org_entities

# %%
valid_countries = {country.name for country in pycountry.countries}

def extract_country(gpe_entities):
    """Returns valid country name from GPE entities for each affiliation"""
    # Consider these example entities: ['Amsterdam', 'Amsterdam', 'The Netherlands'] ['San Sebastián de', 'Madrid']['Republic of China']
    if gpe_entities:
        return next((gpe for gpe in gpe_entities if gpe in valid_countries), None)
    return None

# %%
def get_institution_name(org_entities):
    """Returns the institution name for each affiliation"""
    valid_institutions = ["University", "Institute",
                          "College", "Hospital", "Center"]

    for institution in org_entities:
        for valid_institution in valid_institutions:
            if valid_institution in institution:
                return institution
    return None

# %% [markdown]
# **Extracting country from affiliation name**
# - Multiple tokens from extracting GPE(countries, cities, names)
# - Some have no country names but have city names
# - Some countries have "The" in front
# - Not sure why Madrid didn't work
# - Some have repeated names

# %% [markdown]
# **Extracting institution name from affiliation name**
# - multiple tokens
# - Looking at the institutes.csv, I should get the ones with university in them?

# %% [markdown]
# ## Challenge 4: RapidFuzz

# %% [markdown]
# Assumptions:
# - Threshold similarity score of 90% considered a match
# - matching based on names only
# - case and minor differences: handling case sensitivity and small variations default

# %%
pubmed_df = pd.read_csv("../cleaned_data/pubmed_output_test.csv")
grid_df = pd.read_csv("../raw_data/institutes.csv")

# %%
grid_map = grid_df.set_index('name').to_dict()['grid_id']


def match_org_to_grid(org_entities):
    """Matches the org_entities to GRID dataset institutions with RapidFuzz"""
    best_match = None
    best_match_id = None

    for org in org_entities:
        match = process.extractOne(org, grid_map.keys(
        ), scorer=Levenshtein.normalized_similarity, score_cutoff=0.9)
        if match and match[1] >= 0.9:
            print(match)
            best_match = match[0]
            best_match_id = grid_map[best_match]
            break
    print(f"2: {(best_match, best_match_id)}")
    return (best_match, best_match_id)

# %%
countries = []
institution_names = []
matched_institutions_grid = []
matched_grid_ids = []

pubmed_df["Affiliation name"] = pubmed_df["Affiliation name"].astype(str)
pubmed_df["nlp"] = pubmed_df["Affiliation name"].apply(
    extract_entities)


pubmed_df["Country"] = pubmed_df["nlp"].apply(extract_gpe_entities)
pubmed_df["Institution name"] = pubmed_df["nlp"].apply(extract_org_entities)

pubmed_df["Country"] = pubmed_df["Country"].apply(extract_country)

grid = pubmed_df["Institution name"].apply(
    match_org_to_grid)

pubmed_df[["Institution GRID name", "Institution GRID id"]] = pd.DataFrame(grid.to_list())

            # #challenge 4 
            # grid_name, grid_id = match_org_to_grid(org_entities)

pubmed_df.head()

pubmed_df.to_csv("pubmed_output_test.csv", index=False)
# pubmed_df["Affiliation country"] = extract_country(pubmed_df["nlp"])
# Out:
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('Hospital Universitario de Fuenlabrada', 1.0, 4791)
# 2: ('Hospital Universitario de Fuenlabrada', 'grid.411242.0')
# 2: (None, None)
# 2: (None, None)
# ('Haukeland University Hospital', 1.0, 5426)
# 2: ('Haukeland University Hospital', 'grid.412008.f')
# ('Haukeland University Hospital', 1.0, 5426)
# 2: ('Haukeland University Hospital', 'grid.412008.f')
# 2: (None, None)
# ('Wuhan University', 1.0, 1696)
# 2: ('Wuhan University', 'grid.49470.3e')
# ('Wuhan University', 1.0, 1696)
# 2: ('Wuhan University', 'grid.49470.3e')
# ('Wuhan University', 1.0, 1696)
# 2: ('Wuhan University', 'grid.49470.3e')
# ('Wuhan University', 1.0, 1696)
# 2: ('Wuhan University', 'grid.49470.3e')
# 2: (None, None)
# ('Wuhan University', 1.0, 1696)
# 2: ('Wuhan University', 'grid.49470.3e')
# ('Wuhan University', 1.0, 1696)
# 2: ('Wuhan University', 'grid.49470.3e')
# 2: (None, None)
# 2: (None, None)
# ('University of Udine', 1.0, 239)
# 2: ('University of Udine', 'grid.5390.f')
# 2: (None, None)
# ("University of L'Aquila", 1.0, 2045)
# 2: ("University of L'Aquila", 'grid.158820.6')
# 2: (None, None)
# 2: (None, None)
# ('Shifa International Hospital', 1.0, 8720)
# 2: ('Shifa International Hospital', 'grid.415704.3')
# ('Shifa International Hospital', 1.0, 8720)
# 2: ('Shifa International Hospital', 'grid.415704.3')
# ('Shifa International Hospital', 1.0, 8720)
# 2: ('Shifa International Hospital', 'grid.415704.3')
# ('Shifa International Hospital', 1.0, 8720)
# 2: ('Shifa International Hospital', 'grid.415704.3')
# ('Shifa International Hospital', 1.0, 8720)
# 2: ('Shifa International Hospital', 'grid.415704.3')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('Johns Hopkins University School of Medicine', 1.0, 61778)
# 2: ('Johns Hopkins University School of Medicine', 'grid.471401.7')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('University Hospital', 1.0, 40778)
# 2: ('University Hospital', 'grid.449710.f')
# 2: (None, None)
# ('Haukeland University Hospital', 1.0, 5426)
# 2: ('Haukeland University Hospital', 'grid.412008.f')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('Oklahoma Medical Research Foundation', 1.0, 3479)
# 2: ('Oklahoma Medical Research Foundation', 'grid.274264.1')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('Instituto de Investigaciones Marinas', 0.9166666666666666, 11631)
# 2: ('Instituto de Investigaciones Marinas', 'grid.419099.c')
# ('Saarland University', 1.0, 857)
# 2: ('Saarland University', 'grid.11749.3a')
# ('Saarland University', 1.0, 857)
# 2: ('Saarland University', 'grid.11749.3a')
# ('Saarland University', 1.0, 857)
# 2: ('Saarland University', 'grid.11749.3a')
# ('Saarland University', 1.0, 857)
# 2: ('Saarland University', 'grid.11749.3a')
# ('Uppsala University', 1.0, 622)
# 2: ('Uppsala University', 'grid.8993.b')
# ('Uppsala University', 1.0, 622)
# 2: ('Uppsala University', 'grid.8993.b')
# ('Uppsala University', 1.0, 622)
# 2: ('Uppsala University', 'grid.8993.b')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('University of Toronto', 1.0, 1108)
# 2: ('University of Toronto', 'grid.17063.33')
# ('University of Toronto', 1.0, 1108)
# 2: ('University of Toronto', 'grid.17063.33')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('Zunyi Medical University', 1.0, 10166)
# 2: ('Zunyi Medical University', 'grid.417409.f')
# ('Zunyi Medical University', 1.0, 10166)
# 2: ('Zunyi Medical University', 'grid.417409.f')
# ('Zunyi Medical University', 1.0, 10166)
# 2: ('Zunyi Medical University', 'grid.417409.f')
# ('Zunyi Medical University', 1.0, 10166)
# 2: ('Zunyi Medical University', 'grid.417409.f')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('Osaka University', 1.0, 2003)
# 2: ('Osaka University', 'grid.136593.b')
# ('Osaka University', 1.0, 2003)
# 2: ('Osaka University', 'grid.136593.b')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('Tianjin Medical University General Hospital', 1.0, 5993)
# 2: ('Tianjin Medical University General Hospital', 'grid.412645.0')
# ('Tianjin Medical University General Hospital', 1.0, 5993)
# 2: ('Tianjin Medical University General Hospital', 'grid.412645.0')
# ('Tianjin Medical University General Hospital', 1.0, 5993)
# 2: ('Tianjin Medical University General Hospital', 'grid.412645.0')
# ('Tianjin Medical University General Hospital', 1.0, 5993)
# 2: ('Tianjin Medical University General Hospital', 'grid.412645.0')
# ('Tianjin Medical University General Hospital', 1.0, 5993)
# 2: ('Tianjin Medical University General Hospital', 'grid.412645.0')
# ('Tianjin Medical University General Hospital', 1.0, 5993)
# 2: ('Tianjin Medical University General Hospital', 'grid.412645.0')
# ('Tianjin Medical University General Hospital', 1.0, 5993)
# 2: ('Tianjin Medical University General Hospital', 'grid.412645.0')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('National Chung Hsing University', 1.0, 2878)
# 2: ('National Chung Hsing University', 'grid.260542.7')
# 2: (None, None)
# ('National Cheng Kung University', 1.0, 1790)
# 2: ('National Cheng Kung University', 'grid.64523.36')
# ('Chung Shan Medical University', 1.0, 5109)
# 2: ('Chung Shan Medical University', 'grid.411641.7')
# ('National Cheng Kung University', 1.0, 1790)
# 2: ('National Cheng Kung University', 'grid.64523.36')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('University Medical Center Freiburg', 1.0, 490)
# 2: ('University Medical Center Freiburg', 'grid.7708.8')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('University of Colorado Denver', 1.0, 2297)
# 2: ('University of Colorado Denver', 'grid.241116.1')
# 2: (None, None)
# ('Lund University', 1.0, 125)
# 2: ('Lund University', 'grid.4514.4')
# ('Stanford University School of Medicine', 1.0, 61770)
# 2: ('Stanford University School of Medicine', 'grid.471392.a')
# ('Cedars-Sinai Medical Center', 1.0, 1709)
# 2: ('Cedars-Sinai Medical Center', 'grid.50956.3f')
# ('Cedars-Sinai Medical Center', 1.0, 1709)
# 2: ('Cedars-Sinai Medical Center', 'grid.50956.3f')
# ('Cedars-Sinai Medical Center', 1.0, 1709)
# 2: ('Cedars-Sinai Medical Center', 'grid.50956.3f')
# 2: (None, None)
# 2: (None, None)
# ('National Institutes of Health', 1.0, 1928)
# 2: ('National Institutes of Health', 'grid.94365.3d')
# ('National Institutes of Health', 1.0, 1928)
# 2: ('National Institutes of Health', 'grid.94365.3d')
# ('National Institutes of Health', 1.0, 1928)
# 2: ('National Institutes of Health', 'grid.94365.3d')
# ('National Institutes of Health', 1.0, 1928)
# 2: ('National Institutes of Health', 'grid.94365.3d')
# ('National Institutes of Health', 1.0, 1928)
# 2: ('National Institutes of Health', 'grid.94365.3d')
# ('National Institutes of Health', 1.0, 1928)
# 2: ('National Institutes of Health', 'grid.94365.3d')
# ('Fujian Medical University', 1.0, 2652)
# 2: ('Fujian Medical University', 'grid.256112.3')
# ('Fujian Medical University', 1.0, 2652)
# 2: ('Fujian Medical University', 'grid.256112.3')
# ('Fujian Medical University', 1.0, 2652)
# 2: ('Fujian Medical University', 'grid.256112.3')
# ('Fujian Medical University', 1.0, 2652)
# 2: ('Fujian Medical University', 'grid.256112.3')
# ('Fujian Medical University', 1.0, 2652)
# 2: ('Fujian Medical University', 'grid.256112.3')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('University of Sao Paulo', 1.0, 871)
# 2: ('University of Sao Paulo', 'grid.11899.38')
# 2: (None, None)
# ('University of Sao Paulo', 1.0, 871)
# 2: ('University of Sao Paulo', 'grid.11899.38')
# 2: (None, None)
# 2: (None, None)
# ('University of Sao Paulo', 1.0, 871)
# 2: ('University of Sao Paulo', 'grid.11899.38')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('Affiliated Hospital of Southwest Medical University', 1.0, 78367)
# 2: ('Affiliated Hospital of Southwest Medical University', 'grid.488387.8')
# 2: (None, None)
# 2: (None, None)
# ('Nantong University', 1.0, 2875)
# 2: ('Nantong University', 'grid.260483.b')
# ('Nantong University', 1.0, 2875)
# 2: ('Nantong University', 'grid.260483.b')
# ('Nantong University', 1.0, 2875)
# 2: ('Nantong University', 'grid.260483.b')
# ('Nantong University', 1.0, 2875)
# 2: ('Nantong University', 'grid.260483.b')
# ('Nantong University', 1.0, 2875)
# 2: ('Nantong University', 'grid.260483.b')
# ('Nantong University', 1.0, 2875)
# 2: ('Nantong University', 'grid.260483.b')
# ('Nantong University', 1.0, 2875)
# 2: ('Nantong University', 'grid.260483.b')
# ('Nantong University', 1.0, 2875)
# 2: ('Nantong University', 'grid.260483.b')
# ('Nantong University', 1.0, 2875)
# 2: ('Nantong University', 'grid.260483.b')
# ('Nantong University', 1.0, 2875)
# 2: ('Nantong University', 'grid.260483.b')
# ('Nantong University', 1.0, 2875)
# 2: ('Nantong University', 'grid.260483.b')
# ('Nantong University', 1.0, 2875)
# 2: ('Nantong University', 'grid.260483.b')
# ('Newcastle University', 1.0, 5)
# 2: ('Newcastle University', 'grid.1006.7')
# ('Newcastle University', 1.0, 5)
# 2: ('Newcastle University', 'grid.1006.7')
# ('Royal Victoria Infirmary', 1.0, 11849)
# 2: ('Royal Victoria Infirmary', 'grid.419334.8')
# ('Newcastle University', 1.0, 5)
# 2: ('Newcastle University', 'grid.1006.7')
# 2: (None, None)
# 2: (None, None)
# ('University Hospital', 1.0, 40778)
# 2: ('University Hospital', 'grid.449710.f')
# ('University Hospital', 1.0, 40778)
# 2: ('University Hospital', 'grid.449710.f')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('University Hospital', 1.0, 40778)
# 2: ('University Hospital', 'grid.449710.f')
# ('Kyoto Prefectural University of Medicine', 1.0, 3464)
# 2: ('Kyoto Prefectural University of Medicine', 'grid.272458.e')
# 2: (None, None)
# 2: (None, None)
# ('Department of Virology', 0.9090909090909091, 53394)
# 2: ('Department of Virology', 'grid.462718.e')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('Department of Virology', 0.9090909090909091, 53394)
# 2: ('Department of Virology', 'grid.462718.e')
# 2: (None, None)
# 2: (None, None)
# ('Department of Virology', 0.9090909090909091, 53394)
# 2: ('Department of Virology', 'grid.462718.e')
# 2: (None, None)
# ('University Hospital', 1.0, 40778)
# 2: ('University Hospital', 'grid.449710.f')
# 2: (None, None)
# 2: (None, None)
# ('Cathay General Hospital', 1.0, 6773)
# 2: ('Cathay General Hospital', 'grid.413535.5')
# ('Cathay General Hospital', 1.0, 6773)
# 2: ('Cathay General Hospital', 'grid.413535.5')
# ('National Taiwan University Hospital', 1.0, 5505)
# 2: ('National Taiwan University Hospital', 'grid.412094.a')
# ('Fu Jen Catholic University', 1.0, 2650)
# 2: ('Fu Jen Catholic University', 'grid.256105.5')
# ('National University of Singapore', 1.0, 98)
# 2: ('National University of Singapore', 'grid.4280.e')
# ('National University of Singapore', 1.0, 98)
# 2: ('National University of Singapore', 'grid.4280.e')
# ('Singapore National Eye Center', 1.0, 11790)
# 2: ('Singapore National Eye Center', 'grid.419272.b')
# ('Singapore Eye Research Institute', 1.0, 3465)
# 2: ('Singapore Eye Research Institute', 'grid.272555.2')
# 2: (None, None)
# ('Karolinska Institute', 0.9523809523809523, 146)
# 2: ('Karolinska Institute', 'grid.4714.6')
# ('Uppsala University', 1.0, 622)
# 2: ('Uppsala University', 'grid.8993.b')
# ('Uppsala University', 1.0, 622)
# 2: ('Uppsala University', 'grid.8993.b')
# ('Uppsala University', 1.0, 622)
# 2: ('Uppsala University', 'grid.8993.b')
# ('Uppsala University', 1.0, 622)
# 2: ('Uppsala University', 'grid.8993.b')
# ('Uppsala University', 1.0, 622)
# 2: ('Uppsala University', 'grid.8993.b')
# ('Karolinska Institute', 0.9523809523809523, 146)
# 2: ('Karolinska Institute', 'grid.4714.6')
# ('Uppsala University', 1.0, 622)
# 2: ('Uppsala University', 'grid.8993.b')
# ('Tel Aviv University', 0.9473684210526316, 885)
# 2: ('Tel Aviv University', 'grid.12136.37')
# ('Tel Aviv University', 0.9473684210526316, 885)
# 2: ('Tel Aviv University', 'grid.12136.37')
# 2: (None, None)
# 2: (None, None)
# ('Barzilai Medical Center', 1.0, 7436)
# 2: ('Barzilai Medical Center', 'grid.414259.f')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('University of Florida', 1.0, 1027)
# 2: ('University of Florida', 'grid.15276.37')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('University of Technology', 1.0, 74019)
# 2: ('University of Technology', 'grid.483960.0')
# ('University of Technology', 1.0, 74019)
# 2: ('University of Technology', 'grid.483960.0')
# ('University of Technology', 1.0, 74019)
# 2: ('University of Technology', 'grid.483960.0')
# ('University of Technology', 1.0, 74019)
# 2: ('University of Technology', 'grid.483960.0')
# 2: (None, None)
# ('University of Technology', 1.0, 74019)
# 2: ('University of Technology', 'grid.483960.0')
# 2: (None, None)
# 2: (None, None)
# ('University of Technology', 1.0, 74019)
# 2: ('University of Technology', 'grid.483960.0')
# 2: (None, None)
# ('Yale University', 1.0, 1666)
# 2: ('Yale University', 'grid.47100.32')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('University of Leeds', 1.0, 690)
# 2: ('University of Leeds', 'grid.9909.9')
# ('University of Leeds', 1.0, 690)
# 2: ('University of Leeds', 'grid.9909.9')
# ('Glasgow Caledonian University', 1.0, 207)
# 2: ('Glasgow Caledonian University', 'grid.5214.2')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('Institute of Health Economics', 1.0, 7855)
# 2: ('Institute of Health Economics', 'grid.414721.5')
# 2: (None, None)
# 2: (None, None)
# ('Leeds Community Healthcare NHS Trust', 1.0, 31236)
# 2: ('Leeds Community Healthcare NHS Trust', 'grid.439761.e')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('University of Leeds', 1.0, 690)
# 2: ('University of Leeds', 'grid.9909.9')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# ('First Affiliated Hospital of Anhui Medical University', 0.9298245614035088, 6021)
# 2: ('First Affiliated Hospital of Anhui Medical University', 'grid.412679.f')
# ('First Affiliated Hospital of Anhui Medical University', 0.9298245614035088, 6021)
# 2: ('First Affiliated Hospital of Anhui Medical University', 'grid.412679.f')
# ('First Affiliated Hospital of Anhui Medical University', 0.9298245614035088, 6021)
# 2: ('First Affiliated Hospital of Anhui Medical University', 'grid.412679.f')
# ('First Affiliated Hospital of Anhui Medical University', 0.9298245614035088, 6021)
# 2: ('First Affiliated Hospital of Anhui Medical University', 'grid.412679.f')
# ('McGill University', 1.0, 1000)
# 2: ('McGill University', 'grid.14709.3b')
# ('McGill University', 1.0, 1000)
# 2: ('McGill University', 'grid.14709.3b')
# ('McGill University', 1.0, 1000)
# 2: ('McGill University', 'grid.14709.3b')
# ('McGill University', 1.0, 1000)
# 2: ('McGill University', 'grid.14709.3b')
# ('McGill University', 1.0, 1000)
# 2: ('McGill University', 'grid.14709.3b')
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)
# 2: (None, None)

# %%
# Create and save new columns(affiliation country and affiliaiton institution name) to csv

# countries = []
# institution_names = []
# matched_institutions_grid = []
# matched_grid_ids = []

# for article in root.findall("PubmedArticle"):
#     for author in article.findall(".//AuthorList/Author"):
#         for affiliation in author.findall("AffiliationInfo/Affiliation"):
#             affiliation_text = affiliation.text
#             gpe_entities, org_entities = extract_entities(affiliation_text)

#             #challenge 3
#             country = extract_country(gpe_entities)
#             # institution_name = get_institution_name(org_entities)

#             #challenge 4 
#             grid_name, grid_id = match_org_to_grid(org_entities)

#             countries.append(country)
#             # institution_names.append(institution_name)
#             matched_institutions_grid.append(grid_name)
#             matched_grid_ids.append(grid_id)

# pubmed_df["Affiliation country"] = countries
# # pubmed_df["Affiliation institution name"] = institution_names
# pubmed_df["Affiliation institution name (GRID)"] = matched_institutions_grid
# pubmed_df["Affiliation institution GRID ID"] = matched_grid_ids

# pubmed_df.to_csv("../cleaned_data/pubmed_output_test.csv", index=False)



#Levenshtein 0.8 -> 14s
# Levenshtein 0.9 -> 12s
# Levenshtein 0.9(country gpe reverse) -> 12.6s
# Levenshtein 0.9(country gpe reverse)w/out processor -> 5.6s [5.8s with next(country)]

# %%
##test using smaller dataset

# countries = []
# institution_names = []
# matched_institutions_grid = []
# matched_grid_ids = []

# for article in root.findall("PubmedArticle"):
#     for author in article.findall(".//AuthorList/Author"):
#         for affiliation in author.findall("AffiliationInfo/Affiliation"):
#             affiliation_text = affiliation.text
#             gpe_entities, org_entities = extract_entities(affiliation_text)

#             # challenge 3
#             country = extract_country(gpe_entities)
#             # institution_name = get_institution_name(org_entities)

#             # challenge 4
#             grid_name, grid_id = match_org_to_grid(org_entities)

#             countries.append(country)
#             # institution_names.append(institution_name)
#             matched_institutions_grid.append(grid_name)
#             matched_grid_ids.append(grid_id)

# pubmed_df["Affiliation country"] = countries
# # pubmed_df["Affiliation institution name"] = institution_names
# pubmed_df["Affiliation institution name (GRID)"] = matched_institutions_grid
# pubmed_df["Affiliation institution GRID ID"] = matched_grid_ids

# pubmed_df.to_csv("../cleaned_data/pubmed_output_test.csv", index=False)

# #rapidfuzz -> 9secs
# #levenshtein 0.9 -> 7s
# #levenshtein 0.8 -> 9s
